# %%
print ("Create a pipline")
# Out:
# Create a pipline

# %% [markdown]
# Добавление простых математических операций

# %%
print (2+2)
print (4*4)
print (8/2)
print (2+2*2)
# Out:
# 4
# 16
# 4.0
# 6
